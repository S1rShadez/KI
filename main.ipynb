# %%
import pandas as pd
import matplotlib.pyplot as plt

# data set
dataframe = pd.read_excel("Ruter_data.xlsx")

# %%
dataframe.head()
# Out:
#                              TurId       Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00 2020-08-10  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00 2020-08-03  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# ...

# %%
dataframe.shape
# Out:
# (6000, 17)

# %% [markdown]
# # fiveFeatures = ['Dato', 'Linjefylke', 'Passasjerer_Ombord', 'Kommune', 'Linjetype']

# %%
plt.hist(dataframe.Kommune, bins=34, rwidth=0.8)
plt.xlabel('Kommune')
plt.ylabel('Antall turer')
plt.xticks(rotation=90)
plt.show()

# %%
plt.hist(dataframe.Dato, bins=7, rwidth=0.8)
plt.xlabel('Holdeplass fra')
plt.ylabel('Antall turer')
plt.xticks(rotation=90)
plt.show()

# %%
plt.hist(dataframe.Linjetype, bins=4)
plt.xlabel('Linjetype')
plt.ylabel('Antall')
plt.show()

# %%
plt.hist(dataframe.Linjefylke)
plt.xlabel('Linjefylke')
plt.ylabel('Antall turer')
plt.xticks(rotation=90)
plt.show()

# %%
plt.hist(dataframe.Passasjerer_Ombord, bins=24, rwidth=0.8)
plt.xlabel('Passasjerer ombord')
plt.ylabel('Antall turer')
plt.xticks(rotation=90)
plt.show()
